# %% [markdown]
# # Actividad - Ecuaciones diferenciales

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1. Resolver numéricamente con `solve_ivp` la siguiente ecuación diferencial:
# $$\frac{dx}{dt}=\frac{x}{t+1}$$

# %%
from scipy.integrate import solve_ivp, odeint

# %%
def fun(x,t):
    return x/(t+1)

# %% [markdown]
# Grafique con condición inicial $x_0 = 2$

# %%
def fun(x,t):
    return x/(t+1)

# %%
t = np.linspace(0,50,500)
x0 = 2

x = odeint(fun,x0,t)
x= x[:,0]

plt.figure()
plt.plot(t,x, label="Solucion numerica")
plt.xlabel("Años")
plt.legend(loc="best")
plt.grid()

# %% [markdown]
# 2. Encuentre la solución numérica para un oscilador armónico simple:
#
# $$
# \frac{d^2 x}{dt^2} +  \omega_{0}^2 x = 0.
# $$
# Donde $x_0=0.5$, $\dot{x}_0=0.1$ y $\omega_0=3$.

# %% [markdown]
# $$ v(t) = \frac{dx(t)}{dt}$$

# %% [markdown]
# $$ a(t) = \frac{d^2x(t)}{dt^2} = \frac{dv(t)}{dt}$$

# %% [markdown]
# $$ \frac{dx(t)}{dt}= v(t) $$

# %% [markdown]
# 2.1 Defina una función, cuyos argumentos de entrada sean:
#
#
# 1. el tiempo $t$,
# 2. el arreglo $[x,\dot{x}]$.
#
# Y la salida:
#
# 1. el arreglo $[\dot{x},\ddot{x}]$.
#
#   Considerando el argumento de la frecuencia natural $\omega_0$ debe ser una variable global.

# %%
w0= 3
x0= 0.5
dx0= 0.1

def dX(t, X):
    x = X[0]
    dx = X[1]
    return np.asarray([dx, -w0**2*x])
tspan= [0,10]

sol_x = solve_ivp(dX, tspan, [x0,dx0 ], max_step=01.)

# %% [markdown]
# ##### X = np.linspace(0.5, 0.1)
# def fun2(t,X):
#     return dx, d2*x

# %% [markdown]
# Grafique

# %%
plt.figure()

plt.plot(sol_x.t, sol_x.y[0, :], "r", label="Solucion numerica")

plt.xlabel("Tiempo")
plt.ylabel("y")
plt.legend(loc="best")
plt.grid()

# %% [markdown]
# Asigne a los parámetros de la solución analítica $C_1=x_0$ y $C_2=\frac{\dot{x}_0}{\omega_0}$.

# %%
def fxa (t, w0,x0, dx0):
    C1 = x0
    C2= dx0/w0
    return C1*np.cos(w0*t)+ C2*np.sin(w0*t)

# %%
plt.figure()

plt.plot(sol_x.t, sol_x.y[0, :], "r", label="Solucion numerica")

t = np.linspace(0,10,1000)
posA = fxa(t, w0, x0, dx0)
plt.plot(t, posA, "b", label="Solucion analitica")


plt.xlabel("Tiempo")
plt.ylabel("y")
plt.legend(loc="best")
plt.grid()

# %% [markdown]
# Redefina la función para graficarla (con la palabra reservada ***def***) en un intervalo de tiempo de 0 a 2 segundos. Comparela en un mismo grafico con la solución numérica obtenida.
